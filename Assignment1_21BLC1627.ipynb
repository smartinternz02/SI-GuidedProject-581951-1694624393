# %% [markdown]
# ## Assignment-1 by Aditya Raj Srivastava

# %%
import pandas as pd

# %%
from numpy import NaN

# %% [markdown]
# ![assig1.png](data:image/png;base64,...)

# %% [markdown]
# ## Task - 1 Create a pandas dataframe (DataFrame name as 'df') (10 observation and 5 features)

# %%
dfdata=  {
    'Name': ['Arjun', 'Abhay', 'Amir', 'Ram', 'Shyam', 'Shiina', 'Gulabo', 'Sitabo', 'Andrew', 'Garfield'],
    'Age': [25, 32, 45, 28, 30, 22, 37, 41, 29, 33],
    'Weight': [60, 75, 82, 68, 57, 63, 70, 89, 55, 72],
    'Height': [165, 180, 175, 160, 163, 170, NaN, 190, 150, 175],
    'Temp': [98, 97, 98.1, 99.1, 98.8, 98.6, NaN , 98.9, 99.1, 98.2]
}
dfdata

df=pd.DataFrame(dfdata)
df
# Out:
#        Name  Age  Weight  Height  Temp
# 0     Arjun   25      60   165.0  98.0
# 1     Abhay   32      75   180.0  97.0
# 2      amir   45      82   175.0  98.1
# 3     Akbar   28      68   160.0  99.1
# 4     Shyam   30      57   163.0  98.8
# 5    Shiina   22      63   170.0  98.6
# 6    Gulabo   37      70     NaN   NaN
# 7    Sitabo   41      89   190.0  98.9
# 8    Andrew   29      55   150.0  99.1
# 9  Garfield   33      72   175.0  98.2

# %% [markdown]
# ## Task- 2 Check the info of 'df'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   Weight  10 non-null     int64
#  3   Height  9 non-null      float64
#  4   Temp    9 non-null      float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# ## Task 3- Check the descriptive statistics of 'df'

# %%
df.describe()
# Out:
#              Age     Weight      Height       Temp
# count  10.000000  10.000000    9.000000   9.000000
# mean   32.200000  69.100000  169.777778  98.422222
# std     7.099296  10.918384   11.850926   0.677823
# min    22.000000  55.000000  150.000000  97.000000
# 25%    28.250000  60.750000  163.000000  98.100000
# 50%    31.000000  69.000000  170.000000  98.600000
# 75%    36.000000  74.250000  175.000000  98.900000
# max    45.000000  89.000000  190.000000  99.100000

# %% [markdown]
# ## Task 4- check the 4th index observation with 'loc' slicing operator.

# %%
df.loc[4]
# Out:
# Name      Shyam
# Age          30
# Weight       57
# Height    163.0
# Temp       98.8
# Name: 4, dtype: object

# %% [markdown]
# ## Task 5 - Check the null values in your 'df'

# %%
df.isnull().any()
# Out:
# Name      False
# Age       False
# Weight    False
# Height     True
# Temp       True
# dtype: bool

# %%
#or
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Weight    0
# Height    1
# Temp      1
# dtype: int64

# %% [markdown]
# #Filling the NaN

# %%
df.Height.median()
# Out:
# 170.0

# %%
df.Temp.mean()
# Out:
# 98.42222222222223

# %%
df.Height = df.Height.fillna(df.Height.median())
df.Height
# Out:
# 0    165.0
# 1    180.0
# 2    175.0
# 3    160.0
# 4    163.0
# 5    170.0
# 6    170.0
# 7    190.0
# 8    150.0
# 9    175.0
# Name: Height, dtype: float64

# %%
df.Temp = df.Temp.fillna(df.Temp.mean())
df.Temp
# Out:
# 0    98.000000
# 1    97.000000
# 2    98.100000
# 3    99.100000
# 4    98.800000
# 5    98.600000
# 6    98.422222
# 7    98.900000
# 8    99.100000
# 9    98.200000
# Name: Temp, dtype: float64
